# %%
import sys
import pandas as pd
import numpy as np
import time
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# from collections import Counter
# from itertools import product

# %%
print("Python Version: {}\n".format(sys.version))
print("Pandas Version: {}".format(pd.__version__))
print("Numpy Version: {}".format(np.__version__))
print("matplotlib Version: {}".format(matplotlib.__version__))
# Out:
# Python Version: 3.5.4 |Anaconda, Inc.| (default, Nov  8 2017, 18:11:28)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
#
# Pandas Version: 0.22.0
# Numpy Version: 1.14.0
# matplotlib Version: 2.1.2

# %%
films1 = pd.read_excel("./data/1000GreatestFilms.xls")
# films2 = pd.read_excel("./data/Films-Ranked-1001-2000.xls")

# %%
films1.head(10)
# Out:
#    Pos 2017 2016                   Title               Director  Year Country  \
# 0    1    1    1            Citizen Kane          Welles, Orson  1941     USA
# 1    2    2    2                 Vertigo      Hitchcock, Alfred  1958     USA
# 2    3    3    3   2001: A Space Odyssey       Kubrick, Stanley  1968  UK-USA
# 3    4    4    5  Rules of the Game, The           Renoir, Jean  1939  France
# 4    5    5    4             Tokyo Story          Ozu, Yasujiro  1953   Japan
# 5    6    7    6          Godfather, The  Coppola, Francis Ford  1972     USA
# 6    7    6    7                      8½      Fellini, Federico  1963   Italy
# 7    8    8    8                 Sunrise           Murnau, F.W.  1927     USA
# 8    9    9   10          Searchers, The             Ford, John  1956     USA
# 9   10   10    9           Seven Samurai        Kurosawa, Akira  1954   Japan
#
#    Length                   Genre Colour
# 0     119           Drama-Mystery     BW
# 1     128  Thriller-Drama-Mystery    Col
# 2     139         Science Fiction    Col
# 3     113            Drama-Comedy     BW
# 4     134                   Drama     BW
# 5     175             Drama-Crime    Col
# 6     135                   Drama     BW
# 7     110     Romance-Drama-Crime     BW
# 8     119                 Western    Col
# 9     200    Drama-Action-History     BW

# %%
films1.sample(10)
# Out:
#      Pos 2017 2016                   Title             Director  Year  \
# 913  914  ---  ---          Before Sunrise   Linklater, Richard  1995
# 641  642  623  569       Young Mr. Lincoln           Ford, John  1939
# 175  176  180  189  Rocco and His Brothers    Visconti, Luchino  1960
# 522  523  508  442              Alphaville     Godard, Jean-Luc  1965
# 747  748  805  681        Abraham's Valley  Oliveira, Manoel de  1993
# 326  327  330  350   Make Way for Tomorrow         McCarey, Leo  1937
# 693  694  657  544   Harlan County, U.S.A.      Kopple, Barbara  1976
# 874  875  812  ---                    2046         Wong Kar-wai  2004
# 165  166  166  166    Grapes of Wrath, The           Ford, John  1940
# 480  481  512  425                 Tootsie      Pollack, Sydney  1982
#
#                                   Country  Length  \
# 913                                   USA     101
# 641                                   USA     100
# 175                          Italy-France     180
# 522                                France      95
# 747           Portugal-France-Switzerland     187
# 326                                   USA      92
# 693                                   USA     103
# 874  Hong Kong-China-France-Italy-Germany     129
# 165                                   USA     129
# 480                                   USA     116
#
#                              Genre  Colour
# 913                  Romance-Drama     Col
# 641      Political-Biography-Drama      BW
# 175                          Drama      BW
# 522  Science Fiction-Mystery-Drama      BW
# 747                          Drama     Col
# 326                          Drama      BW
# 693                    Documentary     Col
# 874  Science Fiction-Drama-Romance  Col-BW
# 165                          Drama      BW
# 480                 Romance-Comedy     Col

# %%
films1.tail(10)
# Out:
#       Pos 2017 2016                            Title           Director  Year  \
# 990   991  959  858               Unsere Afrikareise     Kubelka, Peter  1966
# 991   992  980  835  Nightmare Before Christmas, The      Selick, Henry  1993
# 992   993  ---  ---                        They Live    Carpenter, John  1988
# 993   994  943  798                           Heimat       Reitz, Edgar  1984
# 994   995  ---  ---                In Praise of Love   Godard, Jean-Luc  2001
# 995   996  991  ---               Dead Poets Society        Weir, Peter  1989
# 996   997  ---  ---               Husbands and Wives       Allen, Woody  1992
# 997   998  998  ---                     Humanité, L'      Dumont, Bruno  1999
# 998   999  995  ---                            Oasis     Lee Chang-dong  2002
# 999  1000  ---  ---                         Sorcerer  Friedkin, William  1977
#
#           Country  Length                            Genre  Colour
# 990       Austria      13                            Short     Col
# 991           USA      76          Family-Fantasy-Animated     Col
# 992           USA      93  Science Fiction-Thriller-Action     Col
# 993  West Germany     940                            Drama  Col-BW
# 994        France      97                            Drama  Col-BW
# 995           USA     128                            Drama     Col
# 996           USA     107                            Drama     Col
# 997        France     147                            Drama     Col
# 998   South Korea     133                    Romance-Drama     Col
# 999           USA     121         Adventure-Drama-Thriller     Col

# %% [markdown]
# ## Clean Data Types
#
# ### Set the data types of column names to "string"

# %%
films1.columns
# Out:
# Index([     'Pos',       2017,       2016,    'Title', 'Director',     'Year',
#         'Country',   'Length',    'Genre',   'Colour'],
#       dtype='object')

# %% [markdown]
# Note that the `dtype` of the `columns` is still `object` after `astype` tranformation. For a array of string with different lengths, the current recommended way is to use `object` as `dtype`.

# %%
films1.columns = films1.columns.astype(str)
films1.rename(index=str, columns={"Pos":"Rank2018", "2017":"Rank2017", "2016":"Rank2016"}, inplace=True)
films1.columns
# Out:
# Index(['Rank2018', 'Rank2017', 'Rank2016', 'Title', 'Director', 'Year',
#        'Country', 'Length', 'Genre', 'Colour'],
#       dtype='object')

# %%
films1.dtypes
# Out:
# Rank2018     int64
# Rank2017    object
# Rank2016    object
# Title       object
# Director    object
# Year         int64
# Country     object
# Length       int64
# Genre       object
# Colour      object
# dtype: object

# %%
def check_dtype(df):
    for col in df.columns:
        dtype_names, dtype_counts = np.unique([type(x).__name__ for x in df[col]], return_counts=True)
        print("{} unique dtypes in column '{}':".format(len(dtype_names), col))
        pairs = zip(dtype_names,dtype_counts)
        for p in pairs:
            print("{} rows with dtype '{}'".format(p[1], p[0]))
            values, counts = np.unique([x for x in df[col] if type(x).__name__ == p[0]], return_counts=True)

            if len(values) <= 10:
                print("    {} unique values {} with dtype '{}'".format(len(values),values, p[0]))
            else:
                print("    {} unique values with dtype '{}'".format( len(values), p[0]))
        print("\n")

# %%
check_dtype(films1)
# Out:
# 1 unique dtypes in column 'Rank2018':
# 1000 rows with dtype 'int'
#     1000 unique values with dtype 'int'
#
#
# 2 unique dtypes in column 'Rank2017':
# 963 rows with dtype 'int'
#     963 unique values with dtype 'int'
# 37 rows with dtype 'str'
#     1 unique values ['---'] with dtype 'str'
#
#
# 2 unique dtypes in column 'Rank2016':
# 930 rows with dtype 'int'
#     930 unique values with dtype 'int'
# 70 rows with dtype 'str'
#     1 unique values ['---'] with dtype 'str'
#
#
# 2 unique dtypes in column 'Title':
# 2 rows with dtype 'int'
#     2 unique values [1900 2046] with dtype 'int'
# 998 rows with dtype 'str'
#     994 unique values with dtype 'str'
#
#
# 1 unique dtypes in column 'Director':
# 1000 rows with dtype 'str'
#     421 unique values with dtype 'str'
#
#
# 1 unique dtypes in column 'Year':
# 1000 rows with dtype 'int'
#     97 unique values with dtype 'int'
#
#
# 1 unique dtypes in column 'Country':
# 1000 rows with dtype 'str'
#     146 unique values with dtype 'str'
#
#
# 1 unique dtypes in column 'Length':
# 1000 rows with dtype 'int'
#     179 unique values with dtype 'int'
#
#
# 1 unique dtypes in column 'Genre':
# 1000 rows with dtype 'str'
#     322 unique values with dtype 'str'
#
#
# 1 unique dtypes in column 'Colour':
# 1000 rows with dtype 'str'
#     3 unique values ['BW' 'Col' 'Col-BW'] with dtype 'str'

# %%
# fix anomalous dtypes and save memory usage by switching to "shorter" dtypes

# Use 9999 as "missing" because:
# 1. Numpy doesn't support NaN for integers
# 2. The "missing value" in both "Rank2017" and "Rank2016" indicate
#    the rankings are below 1000 (>1000), only censored
films1.loc[films1["Rank2017"]=="---", "Rank2017"] = 9999
films1.loc[films1["Rank2016"]=="---", "Rank2016"] = 9999
films1["Title"] = films1["Title"].astype(str)
films1["Rank2018"] = films1["Rank2018"].astype(np.uint16)
films1["Rank2017"] = films1["Rank2017"].astype(np.uint16)
films1["Rank2016"] = films1["Rank2016"].astype(np.uint16)
films1["Year"] = films1["Year"].astype(np.uint16)
films1["Length"] = films1["Length"].astype(np.uint16)

# %%
films1.dtypes
# Out:
# Rank2018    uint16
# Rank2017    uint16
# Rank2016    uint16
# Title       object
# Director    object
# Year        uint16
# Country     object
# Length      uint16
# Genre       object
# Colour      object
# dtype: object

# %%
check_dtype(films1)
# Out:
# 1 unique dtypes in column 'Rank2018':
# 1000 rows with dtype 'int'
#     1000 unique values with dtype 'int'
#
#
# 1 unique dtypes in column 'Rank2017':
# 1000 rows with dtype 'int'
#     964 unique values with dtype 'int'
#
#
# 1 unique dtypes in column 'Rank2016':
# 1000 rows with dtype 'int'
#     931 unique values with dtype 'int'
#
#
# 1 unique dtypes in column 'Title':
# 1000 rows with dtype 'str'
#     996 unique values with dtype 'str'
#
#
# 1 unique dtypes in column 'Director':
# 1000 rows with dtype 'str'
#     421 unique values with dtype 'str'
#
#
# 1 unique dtypes in column 'Year':
# 1000 rows with dtype 'int'
#     97 unique values with dtype 'int'
#
#
# 1 unique dtypes in column 'Country':
# 1000 rows with dtype 'str'
#     146 unique values with dtype 'str'
#
#
# 1 unique dtypes in column 'Length':
# 1000 rows with dtype 'int'
#     179 unique values with dtype 'int'
#
#
# 1 unique dtypes in column 'Genre':
# 1000 rows with dtype 'str'
#     322 unique values with dtype 'str'
#
#
# 1 unique dtypes in column 'Colour':
# 1000 rows with dtype 'str'
#     3 unique values ['BW' 'Col' 'Col-BW'] with dtype 'str'

# %%
films1.head(10)
# Out:
#    Rank2018  Rank2017  Rank2016                   Title  \
# 0         1         1         1            Citizen Kane
# 1         2         2         2                 Vertigo
# 2         3         3         3   2001: A Space Odyssey
# 3         4         4         5  Rules of the Game, The
# 4         5         5         4             Tokyo Story
# 5         6         7         6          Godfather, The
# 6         7         6         7                      8½
# 7         8         8         8                 Sunrise
# 8         9         9        10          Searchers, The
# 9        10        10         9           Seven Samurai
#
#                 Director  Year Country  Length                   Genre Colour
# 0          Welles, Orson  1941     USA     119           Drama-Mystery     BW
# 1      Hitchcock, Alfred  1958     USA     128  Thriller-Drama-Mystery    Col
# 2       Kubrick, Stanley  1968  UK-USA     139         Science Fiction    Col
# 3           Renoir, Jean  1939  France     113            Drama-Comedy     BW
# 4          Ozu, Yasujiro  1953   Japan     134                   Drama     BW
# 5  Coppola, Francis Ford  1972     USA     175             Drama-Crime    Col
# 6      Fellini, Federico  1963   Italy     135                   Drama     BW
# 7           Murnau, F.W.  1927     USA     110     Romance-Drama-Crime     BW
# 8             Ford, John  1956     USA     119                 Western    Col
# 9        Kurosawa, Akira  1954   Japan     200    Drama-Action-History     BW

# %%
films1.sample(10)
# Out:
#      Rank2018  Rank2017  Rank2016                    Title  \
# 189       190       181       182                      Ran
# 548       549       525       552                Ninotchka
# 108       109       105        96                Jetée, La
# 602       603       644       600       Dancer in the Dark
# 414       415       377       511   Moment of Innocence, A
# 668       669       800       804                  Sur, El
# 404       405       379       339          Star is Born, A
# 743       744       707       601       Holy Mountain, The
# 903       904       843       917           Gregory's Girl
# 777       778       736       836  Sauve qui peut (la vie)
#
#                   Director  Year  \
# 189        Kurosawa, Akira  1985
# 548        Lubitsch, Ernst  1939
# 108          Marker, Chris  1962
# 602        von Trier, Lars  2000
# 414     Makhmalbaf, Mohsen  1996
# 668          Erice, Victor  1983
# 404          Cukor, George  1954
# 743  Jodorowsky, Alejandro  1973
# 903          Forsyth, Bill  1980
# 777       Godard, Jean-Luc  1980
#
#                                                Country  Length  \
# 189                                       France-Japan     161
# 548                                                USA     110
# 108                                             France      27
# 602  Denmark-France-Sweden-Italy-Germany-Norway-Net...     140
# 414                                        Iran-France      78
# 668                                       Spain-France      95
# 404                                                USA     154
# 743                                         Mexico-USA     114
# 903                                                 UK      91
# 777                                 France-Switzerland      87
#
#                            Genre Colour
# 189            War-History-Drama    Col
# 548               Romance-Comedy     BW
# 108  Science Fiction-Drama-Short     BW
# 602                Musical-Drama    Col
# 414                 Drama-Comedy    Col
# 668                Romance-Drama    Col
# 404                Musical-Drama    Col
# 743      Adventure-Drama-Fantasy    Col
# 903               Romance-Comedy    Col
# 777                        Drama    Col

# %%
films1.tail(10)
# Out:
#      Rank2018  Rank2017  Rank2016                            Title  \
# 990       991       959       858               Unsere Afrikareise
# 991       992       980       835  Nightmare Before Christmas, The
# 992       993      9999      9999                        They Live
# 993       994       943       798                           Heimat
# 994       995      9999      9999                In Praise of Love
# 995       996       991      9999               Dead Poets Society
# 996       997      9999      9999               Husbands and Wives
# 997       998       998      9999                     Humanité, L'
# 998       999       995      9999                            Oasis
# 999      1000      9999      9999                         Sorcerer
#
#               Director  Year       Country  Length  \
# 990     Kubelka, Peter  1966       Austria      13
# 991      Selick, Henry  1993           USA      76
# 992    Carpenter, John  1988           USA      93
# 993       Reitz, Edgar  1984  West Germany     940
# 994   Godard, Jean-Luc  2001        France      97
# 995        Weir, Peter  1989           USA     128
# 996       Allen, Woody  1992           USA     107
# 997      Dumont, Bruno  1999        France     147
# 998     Lee Chang-dong  2002   South Korea     133
# 999  Friedkin, William  1977           USA     121
#
#                                Genre  Colour
# 990                            Short     Col
# 991          Family-Fantasy-Animated     Col
# 992  Science Fiction-Thriller-Action     Col
# 993                            Drama  Col-BW
# 994                            Drama  Col-BW
# 995                            Drama     Col
# 996                            Drama     Col
# 997                            Drama     Col
# 998                    Romance-Drama     Col
# 999         Adventure-Drama-Thriller     Col

# %% [markdown]
# ## Column Summary

# %%
films1.describe()
# Out:
#           Rank2018     Rank2017   Rank2016        Year       Length
# count  1000.000000  1000.000000  1000.0000  1000.00000  1000.000000
# mean    500.500000   836.132000  1135.9170  1968.46000   118.534000
# std     288.819436  1818.026589  2447.0971    21.91992    62.570999
# min       1.000000     1.000000     1.0000  1895.00000     1.000000
# 25%     250.750000   250.750000   250.7500  1953.00000    93.000000
# 50%     500.500000   500.500000   500.5000  1969.00000   109.000000
# 75%     750.250000   751.250000   752.2500  1986.00000   129.000000
# max    1000.000000  9999.000000  9999.0000  2011.00000   940.000000

# %%
mean_length = np.nanmean(films1['Length'])
median_length = np.nanmedian(films1['Length'])
min_length = np.nanmin(films1['Length'])
max_length = np.nanmax(films1['Length'])
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.yaxis.grid(True)
ax.set_axisbelow(True) # move axis elements (including grids) at the most underneath layer
ax.hist(films1['Length'], bins=30, range=(0,300), edgecolor='black', color='royalblue')
ax.set_xticks(np.arange(0, np.max(films1["Length"]), 25))
ax.tick_params(length=0)
ax.vlines(x=mean_length, ymin=0, ymax=ax.get_ylim()[1]-10, colors='tomato', linestyles='--')
ax.text(mean_length+8, ax.get_ylim()[1]-20, 'Mean', color='tomato', fontsize=15)
ax.vlines(x=median_length, ymin=0, ymax=ax.get_ylim()[1]-10, colors='maroon', linestyles='--')
ax.text(median_length-60, ax.get_ylim()[1]-20, 'Median', color='maroon', fontsize=15)
ax.set_title('Histogram - films1.Length', loc='center', fontweight='semibold', fontsize=16)
ax.set_xlabel('Film Length')
ax.text(x=-0.06, y=1, s='Counts', transform=ax.transAxes)
plt.tight_layout()
plt.savefig('./image/TSPDT1000LengthHist.png', format='png', dpi=300)
plt.show()

# %% [markdown]
# ## Cross-Column Analysis

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.grid(True)
ax.set_axisbelow(True) # move axis elements (including grids) at the most underneath layer
ax.scatter(films1['Year'], films1['Length'], color='royalblue')
ax.set_ylim((0,300))
ax.set_xticks(np.arange(np.min(films1["Year"]), np.max(films1["Year"]), 10))
for tick in ax.get_xticklabels():
    tick.set_rotation(40)
    tick.set_horizontalalignment('center')
ax.tick_params(length=0)
# ax.text(x=0.1, y=1.1, s='Film Length vs Release Year', fontweight='semibold', fontsize=16, transform=ax.transAxes)
ax.set_title('Film Length vs Release Year', loc='center', fontweight='semibold', fontsize=16)
ax.set_xlabel('Film Release Year')
ax.text(x=-0.06, y=1.05, s='Film Length', transform=ax.transAxes)
plt.tight_layout()
plt.savefig('./image/TSPDT1000LengthVSYear.png', format='png', dpi=300)
plt.show()

# %%
GroupByYr = films1.groupby('Year')
avg_len_yr = GroupByYr['Length'].mean()
mdn_len_yr = GroupByYr['Length'].median()
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.yaxis.grid(True)
ax.set_axisbelow(True) # move axis elements (including grids) at the most underneath layer
line1 = ax.plot(avg_len_yr.index, avg_len_yr.values, color='royalblue')
line1 = ax.plot(mdn_len_yr.index, mdn_len_yr.values, color='maroon')
ax.set_xticks(np.arange(np.min(films1["Year"]), np.max(films1["Year"]), 5))
ax.set_xlim((1920, np.max(films1["Year"])+1))
ax.set_ylim((50, 200))
for tick in ax.get_xticklabels():
    tick.set_rotation(40)
    tick.set_horizontalalignment('center')
ax.tick_params(axis='y', length=0)
ax.set_title('Film Length Group by Release Year', loc='Right', fontweight='semibold', fontsize=16)
ax.set_xlabel('Film Release Year')
ax.text(x=-0.06, y=1.05, s='Film Length', transform=ax.transAxes)
ax.text(x=0.72, y=0.8, s='Mean Length', color='royalblue', fontsize=12, transform=ax.transAxes)
ax.text(x=0.72, y=0.25, s='Median Length', color='maroon', fontsize=12, transform=ax.transAxes)
plt.tight_layout()
plt.savefig('./image/TSPDT1000LengthGBYear.png', format='png', dpi=300)
plt.show()

# %% [markdown]
# ## Unique, Count and Sort

# %%
sorted_films1 = films1.sort_values(by=["Director", "Year"])

# %%
sorted_films1.head(10)
# Out:
#      Rank2018  Rank2017  Rank2016  \
# 719       720       884      9999
# 95         96        98        95
# 860       861       858       938
# 330       331       344       359
# 880       881       888      9999
# 85         86        91        83
# 105       106       110       110
# 657       658       670       675
# 609       610       643       590
# 518       519       531       510
#
#                                                  Title  \
# 719                                          Airplane!
# 95   Jeanne Dielman, 23 Quai du Commerce, 1080 Brux...
# 860                                     News from Home
# 330                                     Kiss Me Deadly
# 880                                     Love and Death
# 85                                          Annie Hall
# 105                                          Manhattan
# 657                                              Zelig
# 609                          Purple Rose of Cairo, The
# 518                             Hannah and Her Sisters
#
#                                     Director  Year  \
# 719  Abrahams, Jim/David Zucker/Jerry Zucker  1980
# 95                          Akerman, Chantal  1975
# 860                         Akerman, Chantal  1976
# 330                          Aldrich, Robert  1955
# 880                             Allen, Woody  1975
# 85                              Allen, Woody  1977
# 105                             Allen, Woody  1979
# 657                             Allen, Woody  1983
# 609                             Allen, Woody  1985
# 518                             Allen, Woody  1986
#
#                          Country  Length                   Genre  Colour
# 719                          USA      86                  Comedy     Col
# 95                Belgium-France     201       Drama-Avant-Garde     Col
# 860  France-Belgium-West Germany      85                   Drama     Col
# 330                          USA     106    Crime-Thriller-Drama      BW
# 880                          USA      82              War-Comedy     Col
# 85                           USA      94          Romance-Comedy     Col
# 105                          USA      96          Romance-Comedy      BW
# 657                          USA      79                  Comedy  Col-BW
# 609                          USA      82  Fantasy-Comedy-Romance  Col-BW
# 518                          USA     106    Drama-Comedy-Romance     Col

# %%
sorted_films1.sample(10)
# Out:
#      Rank2018  Rank2017  Rank2016                    Title  \
# 62         63        58        54  Enfants du paradis, Les
# 794       795       742       688     They Were Expendable
# 607       608       564       606               Local Hero
# 233       234       224       249   Only Angels Have Wings
# 405       406       386       333   Out 1, noli me tangere
# 387       388       396       419             Hustler, The
# 995       996       991      9999       Dead Poets Society
# 787       788       731       847              Seven Women
# 994       995      9999      9999        In Praise of Love
# 97         98       100       109                   Blowup
#
#                     Director  Year   Country  Length                    Genre  \
# 62             Carné, Marcel  1945    France     195            Romance-Drama
# 794               Ford, John  1945       USA     135                War-Drama
# 607            Forsyth, Bill  1983        UK     111             Drama-Comedy
# 233            Hawks, Howard  1939       USA     121  Drama-Adventure-Romance
# 405         Rivette, Jacques  1971    France     729    Comedy-Drama-Thriller
# 387           Rossen, Robert  1961       USA     135              Drama-Sport
# 995              Weir, Peter  1989       USA     128                    Drama
# 787               Ford, John  1966       USA      87            History-Drama
# 994         Godard, Jean-Luc  2001    France      97                    Drama
# 97   Antonioni, Michelangelo  1966  Italy-UK     111            Mystery-Drama
#
#      Colour
# 62       BW
# 794      BW
# 607     Col
# 233      BW
# 405  Col-BW
# 387      BW
# 995     Col
# 787     Col
# 994  Col-BW
# 97      Col

# %%
sorted_films1.tail(10)
# Out:
#      Rank2018  Rank2017  Rank2016                 Title              Director  \
# 468       469       438       490  Scarlet Empress, The  von Sternberg, Josef
# 912       913       905       837              Anatahan  von Sternberg, Josef
# 613       614       612       648         Foolish Wives   von Stroheim, Erich
# 91         92        88       100                 Greed   von Stroheim, Erich
# 524       525       495       564    Wedding March, The   von Stroheim, Erich
# 210       211       199       219    Breaking the Waves       von Trier, Lars
# 723       724       699       609           Idiots, The       von Trier, Lars
# 602       603       644       600    Dancer in the Dark       von Trier, Lars
# 380       381       412       671              Dogville       von Trier, Lars
# 499       500       486       694           Melancholia       von Trier, Lars
#
#      Year                                            Country  Length  \
# 468  1934                                                USA     110
# 912  1953                                              Japan      92
# 613  1922                                                USA     117
# 91   1924                                                USA     140
# 524  1928                                                USA     113
# 210  1996  Denmark-Sweden-France-Netherlands-Norway-Icela...     156
# 723  1998      Denmark-Spain-Sweden-France-Netherlands-Italy     117
# 602  2000  Denmark-France-Sweden-Italy-Germany-Norway-Net...     140
# 380  2003  Denmark-Sweden-France-UK-Germany-Finland-Italy...     177
# 499  2011                      Denmark-Sweden-France-Germany     136
#
#                        Genre Colour
# 468  History-Drama-Biography     BW
# 912                War-Drama     BW
# 613                    Drama     BW
# 91                     Drama     BW
# 524            Romance-Drama     BW
# 210            Romance-Drama    Col
# 723             Drama-Comedy    Col
# 602            Musical-Drama    Col
# 380                    Drama    Col
# 499    Drama-Science Fiction    Col

# %%
df_drctr1 = pd.DataFrame()
df_drctr1["Director"], df_drctr1["CountIn1000"] = np.unique(films1["Director"], return_counts=True)

# %% [markdown]
# The following two cells show two strategies appending elements onto an array (or list). The `np.array` is used in the first one, while python `list` is used the the second one. As one can see, the speed is the same, while `list` approach has the advantage of not having to specify the length in the first place.

# %%
start_time = time.time()
lst_yr = np.empty(len(films1["Director"]))
fst_yr = np.empty(len(films1["Director"]))

for drctr in df_drctr1["Director"]:
    drctr_yr = films1.loc[films1["Director"] == drctr, "Year"]
    np.append(lst_yr, np.max(drctr_yr))
    np.append(fst_yr, np.min(drctr_yr))
    
# print(lst_yr)
# print(fst_yr)

print("--- {} seconds ---".format(time.time()-start_time))
# Out:
# --- 0.39915013313293457 seconds ---

# %%
start_time = time.time()

lst_yr = []
fst_yr = []

for drctr in df_drctr1["Director"]:
    drctr_yr = films1.loc[films1["Director"] == drctr, "Year"]
    
    lst_yr.append(np.max(drctr_yr))
    fst_yr.append(np.min(drctr_yr))

lst_yr = np.array(lst_yr)
fst_yr = np.array(fst_yr)
# print(lst_yr)
# print(fst_yr)

print("--- {} seconds ---".format(time.time()-start_time))
# Out:
# --- 0.3399510383605957 seconds ---

# %%
df_drctr1["LastFilmYear"] = lst_yr
df_drctr1["FirstFilmYear"] = fst_yr

# %%
df_drctr1_sorted = df_drctr1.sort_values(by=["LastFilmYear","CountIn1000"], ascending=[False, False])

# %%
df_drctr1_sorted.head(10)
# Out:
#                        Director  CountIn1000  LastFilmYear  FirstFilmYear
# 226            Malick, Terrence            5          2011           1973
# 420             von Trier, Lars            5          2011           1996
# 363                  Tarr, Béla            3          2011           1994
# 102             Farhadi, Asghar            1          2011           2011
# 391  Weerasethakul, Apichatpong            4          2010           2002
# 134            Guzmán, Patricio            1          2010           2010
# 41               Cameron, James            5          2009           1984
# 139             Haneke, Michael            5          2009           1997
# 233            Martel, Lucrecia            2          2008           2001
# 260          Nolan, Christopher            2          2008           2000

# %%
df_drctr1_sorted.sample(10)
# Out:
#                         Director  CountIn1000  LastFilmYear  FirstFilmYear
# 278                 Penn, Arthur            1          1967           1967
# 135  Gören, Serif & Yilmaz Güney            1          1982           1982
# 200                  Lang, Fritz            9          1959           1922
# 350              Stanton, Andrew            1          2008           2008
# 379                  Vidor, King            3          1949           1928
# 292                Rafelson, Bob            1          1970           1970
# 105                       Fei Mu            1          1948           1948
# 296                Ray, Satyajit            5          1964           1955
# 258                Naruse, Mikio            1          1955           1955
# 304               Resnais, Alain            6          1980           1955

# %%
df_drctr1_sorted.tail(10)
# Out:
#                             Director  CountIn1000  LastFilmYear  FirstFilmYear
# 178    Keaton, Buster/Clyde Bruckman            1          1926           1926
# 176                   Keaton, Buster            2          1925           1924
# 179      Keaton, Buster/Donald Crisp            1          1924           1924
# 181  Keaton, Buster/John G. Blystone            1          1923           1923
# 54             Christensen, Benjamin            1          1922           1922
# 396                    Wiene, Robert            1          1920           1920
# 132                   Griffith, D.W.            4          1919           1915
# 107                 Feuillade, Louis            1          1915           1915
# 257                  Méliès, Georges            1          1902           1902
# 221  Lumière, August & Louis Lumière            1          1895           1895

# %%
films1.loc[films1["Director"]=="Malick, Terrence",:]
# Out:
#      Rank2018  Rank2017  Rank2016               Title          Director  Year  \
# 124       125       127       129            Badlands  Malick, Terrence  1973
# 139       140       140       140      Days of Heaven  Malick, Terrence  1978
# 195       196       210       223  Thin Red Line, The  Malick, Terrence  1998
# 239       240       235       405   Tree of Life, The  Malick, Terrence  2011
# 795       796       776      9999      New World, The  Malick, Terrence  2005
#
#     Country  Length                  Genre Colour
# 124     USA      95            Drama-Crime    Col
# 139     USA      95          Romance-Drama    Col
# 195     USA     170       War-Drama-Action    Col
# 239     USA     139                  Drama    Col
# 795     USA     135  Drama-History-Romance    Col
